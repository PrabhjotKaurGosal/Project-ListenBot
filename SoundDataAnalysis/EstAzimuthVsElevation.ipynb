# %%
# This code analyzes the data through plotting for different directions of the sound source 
# at different elevation angles
#  Estimated Azimuth angle at different Elevation angles

import os
import matplotlib.pyplot as plt
import numpy as np
import librosa
import wave
import librosa as lr
from scipy import signal
from scipy.fftpack import fft,fft2, fftshift, ifft
import math
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from sklearn import preprocessing
import librosa.display

# %%
Elevation_Angle = [50,45,40,35,30,25,20,15,10,5,0]

# Quadrant 4
# The elements in the array are from 50 degree elevation to 0 degree elevation
Azimuth_Angle_30 = [30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30]
Azimuth_Angle_30_estimated_T1 = [17.83604667,18.7904,20.9575,22.2762,23.8984,25.0172,25.0184,26.3998,27.1612,27.2874,27.7887]
Azimuth_Angle_30_estimated_T2 = [55.90713333,55.6936,50.5784,49.3156,44.6281,40.0408,37.5734,32.6561,30.7347,28.2748,29.1159]

Azimuth_Angle_60 = [60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60]
Azimuth_Angle_60_estimated_T1 = [31.45006667,35.5204, 37.7781,40.7001,43.9205,47.6524,50.0490,52.9716,54.5087,55.70255,57.3344]
Azimuth_Angle_60_estimated_T2 = [75.09896667,72.78806667, 71.3002,70.02,66.7609,66.5414,64.9835,63.4144,62.9548,57.6227,55.4489]

# Quadrant 2
Azimuth_Angle_210 = [210, 210, 210, 210, 210, 210, 210, 210, 210, 210, 210]
Azimuth_Angle_210_estimated_T1 = [-161.4467,-160.7271,-155.7294,-154.4822,-153.2198,-151.6877,-151.4314,-149.6100,-147.7546,-147.2173,-146.1512]
Azimuth_Angle_210_estimated_T2 = [-124.8021,-128.8309,-131.2031,-133.9441,-137.7139,-139.2387,-143.7739,-145.1632,-145.8861,-145.5150,-145.8861]

Azimuth_Angle_240 = [240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240]
Azimuth_Angle_240_estimated_T1 = [-147.4839,-144.1953,-139.0001,-136.3974,-132.3474,-130.1165,-125.6895,-123.2824,-121.0463,-118.1957,-112.9465]
Azimuth_Angle_240_estimated_T2 = [-109.3368,-112.1428,-112.5793,-114.3403,-114.5636,-116.5750,-115.8998,-118.6248,-118.3990,-117.7100,-117.2540]

# Quadrant 1
Azimuth_Angle_120 = [120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120]
Azimuth_Angle_120_estimated_T1 = [151.1706,145.9975,145.1705,141.1358,138.5470,136.5492,133.9981,130.6389,128.6887,125.8822,123.2794]
Azimuth_Angle_120_estimated_T2 = [111.2776,112.6693,115.6760,117.0281,119.3169,120.4857,121.6629,121.6593,122.1385,122.6258,125.5430]
Azimuth_Angle_120_estimated_T3 = [136.6332,133.6607,134.0734,131.6872,131.1629,130.3233,129.0534,127.8794,125.5013,124.5142,123.1741]

Azimuth_Angle_150 = [150, 150, 150, 150, 150, 150, 150, 150, 150, 150, 150]
Azimuth_Angle_150_estimated_T1 = [163.2314,161.6868,160.7304,159.6472,157.3346,156.5974,155.6036,154.4819,154.7283,153.7275,152.9656]
Azimuth_Angle_150_estimated_T2 = [123.3358,127.5496,132.0129,137.8404,138.0165,139.5409,142.7769,145.5247,147.3437,150.8839,153.0317]
Azimuth_Angle_150_estimated_T3 = [151.8182,151.9170,152.9051,152.9052,152.2135,152.6087,152.2134,153.0040,152.5098,153.3005,152.6086]


# Quadrant 3
Azimuth_Angle_300 = [300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300]
Azimuth_Angle_300_estimated_T1 = [-33.5949,-37.6331,-40.2154,-43.6072,-48.8290,-51.3198,-53.1617,-58.1963,-60.4079,-61.9302,-63.2777]
Azimuth_Angle_300_estimated_T2 = [-70.6621,-66.761,-64.7444,-62.743,-61.1418,-59.0492,-56.4235,-56.1788,-54.7059,-54.0696,-52.5937]
Azimuth_Angle_300_estimated_T3 = [-47.1673,-49.8874,-50.6285,-51.267,-53.5234,-54.6081,-54.8265,-57.5962,-57.1488,-58.0472,-58.6137]

Azimuth_Angle_330_estimated_T1 = [-20.2327,-21.9304,-22.7871,-24.5179,-26.5260,-26.6538,-29.2180,-30.5162,-31.4450,-32.7856,-33.5949]
Azimuth_Angle_330_estimated_T2 = [-56.4214,-52.9511,-47.9835,-44.0564,-40.4530,-33.5689,-33.7619,-29.9403,-24.1597,-20.9102,-29.2392]
Azimuth_Angle_330_estimated_T3 = [-31.1754,-31.2746,-29.9899,-29.7430,-30.2863,-29.1090,-30.0887,-29.8912,-29.5194,-29.9900,-29.9899]

# %% [markdown]
# #### Quadrant 4 [30, 60]

# %%
m_Azimuth_Angle_30_estimated_T1, b_Azimuth_Angle_30_estimated_T1 = np.polyfit(Elevation_Angle, Azimuth_Angle_30_estimated_T1, 1)
plt.plot(Elevation_Angle, Azimuth_Angle_30_estimated_T1,'go', Elevation_Angle,m_Azimuth_Angle_30_estimated_T1*np.array(Elevation_Angle) + b_Azimuth_Angle_30_estimated_T1, 'g--',label="Est_azimuth_ch13(T1)")
plt.xticks([50,45,40,35,30,25,20,15,10,5,0])   

m_Azimuth_Angle_30_estimated_T2, b_Azimuth_Angle_30_estimated_T2 = np.polyfit(Elevation_Angle, Azimuth_Angle_30_estimated_T2, 1)
plt.plot(Elevation_Angle, Azimuth_Angle_30_estimated_T2, 'ro' , Elevation_Angle,m_Azimuth_Angle_30_estimated_T2*np.array(Elevation_Angle) + b_Azimuth_Angle_30_estimated_T2, 'r--',label = "Est_azimuth_ch23(T2)")

plt.plot([0,50], [30,30], 'k--',label = "True azimuth angle")

plt.xlabel('Elevation angle in degrees')
plt.ylabel('Azimuth angle in degrees')
plt.title('Estimated azimuth angle versus elevation of the source')
plt.legend()

# print("Compare the rate of change of the estimated azimuth angle when true azimuth for the sound source is 30 degrees")
# if(abs(m_Azimuth_Angle_30_estimated_T1)>abs(m_Azimuth_Angle_30_estimated_T2)):
#     print("The rate of change of estimated angle using ch13(T1) is larger than the estimated angle using ch23 (T2) ")
# elif(abs(m_Azimuth_Angle_30_estimated_T1)<abs(m_Azimuth_Angle_30_estimated_T2)):
#     print("The rate of change of estimated angle using ch23(T2) is larger than the estimated angle using ch13 (T1) ")
# else:
#     print("The rate of change of estimated angle using ch13(T1) is equal to the estimated angle using ch23 (T2) ")


print("The slope of T1 is: ",m_Azimuth_Angle_30_estimated_T1 )
print("The slope of T2 is: ",m_Azimuth_Angle_30_estimated_T2 )
# Out:
# The slope of T1 is:  -0.2031446666363633
# The slope of T2 is:  0.624611212090909

# %%
m_Azimuth_Angle_60_estimated_T1, b_Azimuth_Angle_60_estimated_T1 = np.polyfit(Elevation_Angle, Azimuth_Angle_60_estimated_T1, 1)
plt.plot(Elevation_Angle, Azimuth_Angle_60_estimated_T1, 'go' ,Elevation_Angle,m_Azimuth_Angle_60_estimated_T1*np.array(Elevation_Angle) + b_Azimuth_Angle_60_estimated_T1, 'g--', label="Est_azimuth_ch13(T1)")
plt.xticks([50, 45, 40,35,30,25,20,15,10,5,0])   

m_Azimuth_Angle_60_estimated_T2, b_Azimuth_Angle_60_estimated_T2 = np.polyfit(Elevation_Angle, Azimuth_Angle_60_estimated_T2, 1)
plt.plot(Elevation_Angle, Azimuth_Angle_60_estimated_T2, 'ro' ,Elevation_Angle,m_Azimuth_Angle_60_estimated_T2*np.array(Elevation_Angle) + b_Azimuth_Angle_60_estimated_T2, 'r--', label = "Est_azimuth_ch23(T2)")

plt.plot([0,50], [60,60], 'k--',label = "True azimuth angle")

plt.xlabel('Elevation angle in degrees')
plt.ylabel('Azimuth angle in degrees')
plt.title('Estimated azimuth angle versus elevation of the source')
plt.legend()

# print("Compare the rate of change of the estimated azimuth angle when true azimuth for the sound source is 60 degrees")
# if(abs(m_Azimuth_Angle_60_estimated_T1)>abs(m_Azimuth_Angle_60_estimated_T2)):
#     print("The rate of change of estimated angle using ch13(T1) is larger than the estimated angle using ch23 (T2) ")
# elif(abs(m_Azimuth_Angle_60_estimated_T1)<abs(m_Azimuth_Angle_60_estimated_T2)):
#     print("The rate of change of estimated angle using ch23(T2) is larger than the estimated angle using ch13 (T1) ")
# else:
#     print("The rate of change of estimated angle using ch13(T1) is equal to the estimated angle using ch23 (T2) ")

print("The slope of T1 is: ",m_Azimuth_Angle_60_estimated_T1 )
print("The slope of T2 is: ",m_Azimuth_Angle_60_estimated_T2 )
# Out:
# The slope of T1 is:  -0.5291155757272717
# The slope of T2 is:  0.36170290914545533

# %% [markdown]
# #### Quadrant 2 [-150 (210), -120 (240)]

# %%
m_Azimuth_Angle_210_estimated_T1, b_Azimuth_Angle_210_estimated_T1 = np.polyfit(Elevation_Angle, Azimuth_Angle_210_estimated_T1, 1)
plt.plot(Elevation_Angle, Azimuth_Angle_210_estimated_T1, 'go' ,Elevation_Angle,m_Azimuth_Angle_210_estimated_T1*np.array(Elevation_Angle) + b_Azimuth_Angle_210_estimated_T1, 'g--', label="Est_azimuth_ch13(T1)")
plt.xticks([50, 45, 40,35,30,25,20,15,10,5,0])   

m_Azimuth_Angle_210_estimated_T2, b_Azimuth_Angle_210_estimated_T2 = np.polyfit(Elevation_Angle, Azimuth_Angle_210_estimated_T2, 1)
plt.plot(Elevation_Angle, Azimuth_Angle_210_estimated_T2, 'ro' ,Elevation_Angle,m_Azimuth_Angle_210_estimated_T2*np.array(Elevation_Angle) + b_Azimuth_Angle_210_estimated_T2, 'r--', label = "Est_azimuth_ch23(T2)")

plt.plot([0,50], [-150,-150], 'k--',label = "True azimuth angle")

plt.xlabel('Elevation angle in degrees')
plt.ylabel('Azimuth angle in degrees')
plt.title('Estimated azimuth angle versus elevation of the source')
plt.legend()

# print("Compare the rate of change of the estimated azimuth angle when true azimuth for the sound source is 210 (-150) degrees")
# if(abs(m_Azimuth_Angle_210_estimated_T1)>abs(m_Azimuth_Angle_210_estimated_T2)):
#     print("The rate of change of estimated angle using ch13(T1) is larger than the estimated angle using ch23 (T2) ")
# elif(abs(m_Azimuth_Angle_210_estimated_T1)<abs(m_Azimuth_Angle_210_estimated_T2)):
#     print("The rate of change of estimated angle using ch23(T2) is larger than the estimated angle using ch13 (T1) ")
# else:
#     print("The rate of change of estimated angle using ch13(T1) is equal to the estimated angle using ch23 (T2) ")

print("The slope of T1 is: ",m_Azimuth_Angle_210_estimated_T1 )
print("The slope of T2 is: ",m_Azimuth_Angle_210_estimated_T2 )
# Out:
# The slope of T1 is:  -0.3017707272727284
# The slope of T2 is:  0.4449156363636341

# %%
m_Azimuth_Angle_240_estimated_T1, b_Azimuth_Angle_240_estimated_T1 = np.polyfit(Elevation_Angle, Azimuth_Angle_240_estimated_T1, 1)
plt.plot(Elevation_Angle, Azimuth_Angle_240_estimated_T1, 'go' ,Elevation_Angle,m_Azimuth_Angle_240_estimated_T1*np.array(Elevation_Angle) + b_Azimuth_Angle_240_estimated_T1, 'g--', label="Est_azimuth_ch13(T1)")
plt.xticks([50, 45, 40,35,30,25,20,15,10,5,0])   

m_Azimuth_Angle_240_estimated_T2, b_Azimuth_Angle_240_estimated_T2 = np.polyfit(Elevation_Angle, Azimuth_Angle_240_estimated_T2, 1)
plt.plot(Elevation_Angle, Azimuth_Angle_240_estimated_T2, 'ro' ,Elevation_Angle,m_Azimuth_Angle_240_estimated_T2*np.array(Elevation_Angle) + b_Azimuth_Angle_240_estimated_T2, 'r--', label = "Est_azimuth_ch23(T2)")

plt.plot([0,50], [-120,-120], 'k--',label = "True azimuth angle")

plt.xlabel('Elevation angle in degrees')
plt.ylabel('Azimuth angle in degrees')
plt.title('Estimated azimuth angle versus elevation of the source')
plt.legend()
# print("Compare the rate of change of the estimated azimuth angle when true azimuth for the sound source is 240 (-120) degrees")
# if(abs(m_Azimuth_Angle_240_estimated_T1)>abs(m_Azimuth_Angle_240_estimated_T2)):
#     print("The rate of change of estimated angle using ch13(T1) is larger than the estimated angle using ch23 (T2) ")
# elif(abs(m_Azimuth_Angle_240_estimated_T1)<abs(m_Azimuth_Angle_240_estimated_T2)):
#     print("The rate of change of estimated angle using ch23(T2) is larger than the estimated angle using ch13 (T1) ")
# else:
#     print("The rate of change of estimated angle using ch13(T1) is equal to the estimated angle using ch23 (T2) ")

print("The slope of T1 is: ",m_Azimuth_Angle_240_estimated_T1 )
print("The slope of T2 is: ",m_Azimuth_Angle_240_estimated_T2 )
# Out:
# The slope of T1 is:  -0.6607903636363655
# The slope of T2 is:  0.1622165454545455

# %% [markdown]
# #### Quadrant 3 [-60 (300), -30 (330)]

# %%
m_Azimuth_Angle_300_estimated_T1, b_Azimuth_Angle_300_estimated_T1 = np.polyfit(Elevation_Angle, Azimuth_Angle_300_estimated_T1, 1)
plt.plot(Elevation_Angle, Azimuth_Angle_300_estimated_T1, 'go' ,Elevation_Angle,m_Azimuth_Angle_300_estimated_T1*np.array(Elevation_Angle) + b_Azimuth_Angle_300_estimated_T1, 'g--', label="Est_azimuth_ch13(T1)")
plt.xticks([50, 45, 40,35,30,25,20,15,10,5,0])   

m_Azimuth_Angle_300_estimated_T2, b_Azimuth_Angle_300_estimated_T2 = np.polyfit(Elevation_Angle, Azimuth_Angle_300_estimated_T2, 1)
plt.plot(Elevation_Angle, Azimuth_Angle_300_estimated_T2, 'ro' ,Elevation_Angle,m_Azimuth_Angle_300_estimated_T2*np.array(Elevation_Angle) + b_Azimuth_Angle_300_estimated_T2, 'r--', label = "Est_azimuth_ch23(T2)")

m_Azimuth_Angle_300_estimated_T3, b_Azimuth_Angle_300_estimated_T3 = np.polyfit(Elevation_Angle, Azimuth_Angle_300_estimated_T3, 1)
plt.plot(Elevation_Angle, Azimuth_Angle_300_estimated_T3, 'bo' ,Elevation_Angle,m_Azimuth_Angle_300_estimated_T3*np.array(Elevation_Angle) + b_Azimuth_Angle_300_estimated_T3, 'b--', label = "Est_azimuth_ch12(T3)")

plt.plot([0,50], [-60,-60], 'k--',label = "True azimuth angle")

plt.xlabel('Elevation angle in degrees')
plt.ylabel('Azimuth angle in degrees')
plt.title('Estimated azimuth angle versus elevation of the source')
plt.legend()

# print("Compare the rate of change of the estimated azimuth angle when true azimuth for the sound source is 300 (-60) degrees")
# if(abs(m_Azimuth_Angle_300_estimated_T1)>abs(m_Azimuth_Angle_300_estimated_T2)):
#     print("The rate of change of estimated angle using ch13(T1) is larger than the estimated angle using ch23 (T2) ")
# elif(abs(m_Azimuth_Angle_300_estimated_T1)<abs(m_Azimuth_Angle_300_estimated_T2)):
#     print("The rate of change of estimated angle using ch23(T2) is larger than the estimated angle using ch13 (T1) ")
# else:
#     print("The rate of change of estimated angle using ch13(T1) is equal to the estimated angle using ch23 (T2) ")


print("The slope of T1 is: ",m_Azimuth_Angle_300_estimated_T1 )
print("The slope of T2 is: ",m_Azimuth_Angle_300_estimated_T2 )
print("The slope of T3 is: ",m_Azimuth_Angle_300_estimated_T3 )
# Out:
# The slope of T1 is:  0.6176196363636356
# The slope of T2 is:  -0.3437632727272731
# The slope of T3 is:  0.2243519999999989

# %%
m_Azimuth_Angle_330_estimated_T1, b_Azimuth_Angle_330_estimated_T1 = np.polyfit(Elevation_Angle, Azimuth_Angle_330_estimated_T1, 1)
plt.plot(Elevation_Angle, Azimuth_Angle_330_estimated_T1, 'go' ,Elevation_Angle,m_Azimuth_Angle_330_estimated_T1*np.array(Elevation_Angle) + b_Azimuth_Angle_330_estimated_T1, 'g--', label="Est_azimuth_ch13(T1)")
plt.xticks([50, 45, 40,35,30,25,20,15,10,5,0])   

m_Azimuth_Angle_330_estimated_T2, b_Azimuth_Angle_330_estimated_T2 = np.polyfit(Elevation_Angle, Azimuth_Angle_330_estimated_T2, 1)
plt.plot(Elevation_Angle, Azimuth_Angle_330_estimated_T2, 'ro' ,Elevation_Angle,m_Azimuth_Angle_330_estimated_T2*np.array(Elevation_Angle) + b_Azimuth_Angle_330_estimated_T2, 'r--', label = "Est_azimuth_ch23(T2)")

m_Azimuth_Angle_330_estimated_T3, b_Azimuth_Angle_330_estimated_T3 = np.polyfit(Elevation_Angle, Azimuth_Angle_330_estimated_T3, 1)
plt.plot(Elevation_Angle, Azimuth_Angle_330_estimated_T3, 'bo' ,Elevation_Angle,m_Azimuth_Angle_330_estimated_T3*np.array(Elevation_Angle) + b_Azimuth_Angle_330_estimated_T3, 'b--', label = "Est_azimuth_ch12(T3)")

plt.plot([0,50], [-30,-30], 'k--',label = "True azimuth angle")

plt.xlabel('Elevation angle in degrees')
plt.ylabel('Azimuth angle in degrees')
plt.title('Estimated azimuth angle versus elevation of the source')
plt.legend()

# print("Compare the rate of change of the estimated azimuth angle when true azimuth for the sound source is 330 (-30) degrees")
# if(abs(m_Azimuth_Angle_330_estimated_T1)>abs(m_Azimuth_Angle_330_estimated_T2)):
#     print("The rate of change of estimated angle using ch13(T1) is larger than the estimated angle using ch23 (T2) ")
# elif(abs(m_Azimuth_Angle_330_estimated_T1)<abs(m_Azimuth_Angle_330_estimated_T2)):
#     print("The rate of change of estimated angle using ch23(T2) is larger than the estimated angle using ch13 (T1) ")
# else:
#     print("The rate of change of estimated angle using ch13(T1) is equal to the estimated angle using ch23 (T2) ")

print("The slope of T1 is: ",m_Azimuth_Angle_330_estimated_T1 )
print("The slope of T2 is: ",m_Azimuth_Angle_330_estimated_T2 )
print("The slope of T3 is: ",m_Azimuth_Angle_330_estimated_T3 )
# Out:
# The slope of T1 is:  0.27435290909090854
# The slope of T2 is:  -0.6735805454545452
# The slope of T3 is:  -0.02250654545454552

# %% [markdown]
# #### Quadrant 1 [120, 150]

# %%
m_Azimuth_Angle_120_estimated_T1, b_Azimuth_Angle_120_estimated_T1 = np.polyfit(Elevation_Angle, Azimuth_Angle_120_estimated_T1, 1)
plt.plot(Elevation_Angle, Azimuth_Angle_120_estimated_T1, 'go' ,Elevation_Angle,m_Azimuth_Angle_120_estimated_T1*np.array(Elevation_Angle) + b_Azimuth_Angle_120_estimated_T1, 'g--', label="Est_azimuth_ch13(T1)")
plt.xticks([50, 45, 40,35,30,25,20,15,10,5,0])   

m_Azimuth_Angle_120_estimated_T2, b_Azimuth_Angle_120_estimated_T2 = np.polyfit(Elevation_Angle, Azimuth_Angle_120_estimated_T2, 1)
plt.plot(Elevation_Angle, Azimuth_Angle_120_estimated_T2, 'ro' ,Elevation_Angle,m_Azimuth_Angle_120_estimated_T2*np.array(Elevation_Angle) + b_Azimuth_Angle_120_estimated_T2, 'r--', label = "Est_azimuth_ch23(T2)")

m_Azimuth_Angle_120_estimated_T3, b_Azimuth_Angle_120_estimated_T3 = np.polyfit(Elevation_Angle, Azimuth_Angle_120_estimated_T3, 1)
plt.plot(Elevation_Angle, Azimuth_Angle_120_estimated_T3, 'bo' ,Elevation_Angle,m_Azimuth_Angle_120_estimated_T3*np.array(Elevation_Angle) + b_Azimuth_Angle_120_estimated_T3, 'b--', label = "Est_azimuth_ch12(T3)")

plt.plot([0,50], [120,120], 'k--',label = "True azimuth angle")

plt.xlabel('Elevation angle in degrees')
plt.ylabel('Azimuth angle in degrees')
plt.title('Estimated azimuth angle versus elevation of the source')
plt.legend()

print("Compare the rate of change of the estimated azimuth angle when true azimuth for the sound source is 120 degrees")
# if(abs(m_Azimuth_Angle_120_estimated_T1)>abs(m_Azimuth_Angle_120_estimated_T2)):
#     print("The rate of change of estimated angle using ch13(T1) is larger than the estimated angle using ch23 (T2) ")
# elif(abs(m_Azimuth_Angle_120_estimated_T1)<abs(m_Azimuth_Angle_120_estimated_T2)):
#     print("The rate of change of estimated angle using ch23(T2) is larger than the estimated angle using ch13 (T1) ")
# else:
#     print("The rate of change of estimated angle using ch13(T1) is equal to the estimated angle using ch23 (T2) ")

print("The slope of T1 is: ",m_Azimuth_Angle_120_estimated_T1 )
print("The slope of T2 is: ",m_Azimuth_Angle_120_estimated_T2 )
print("The slope of T3 is: ",m_Azimuth_Angle_120_estimated_T3 )
# Out:
# Compare the rate of change of the estimated azimuth angle when true azimuth for the sound source is 120 degrees
# The slope of T1 is:  0.5361914545454552
# The slope of T2 is:  -0.25845254545454444
# The slope of T3 is:  0.2533143636363641

# %%
m_Azimuth_Angle_150_estimated_T1, b_Azimuth_Angle_150_estimated_T1 = np.polyfit(Elevation_Angle, Azimuth_Angle_150_estimated_T1, 1)
plt.plot(Elevation_Angle, Azimuth_Angle_150_estimated_T1, 'go' ,Elevation_Angle,m_Azimuth_Angle_150_estimated_T1*np.array(Elevation_Angle) + b_Azimuth_Angle_150_estimated_T1, 'g--', label="Azimuth_est_ch13(T1)")
plt.xticks([50, 45, 40,35,30,25,20,15,10,5,0])   

m_Azimuth_Angle_150_estimated_T2, b_Azimuth_Angle_150_estimated_T2 = np.polyfit(Elevation_Angle, Azimuth_Angle_150_estimated_T2, 1)
plt.plot(Elevation_Angle, Azimuth_Angle_150_estimated_T2, 'ro' ,Elevation_Angle,m_Azimuth_Angle_150_estimated_T2*np.array(Elevation_Angle) + b_Azimuth_Angle_150_estimated_T2, 'r--', label = "Azimuth_est_ch23(T2)")

m_Azimuth_Angle_150_estimated_T3, b_Azimuth_Angle_150_estimated_T3 = np.polyfit(Elevation_Angle, Azimuth_Angle_150_estimated_T3, 1)
plt.plot(Elevation_Angle, Azimuth_Angle_150_estimated_T3, 'bo' ,Elevation_Angle,m_Azimuth_Angle_150_estimated_T3*np.array(Elevation_Angle) + b_Azimuth_Angle_150_estimated_T3, 'b--', label = "Azimuth_est_ch12(T3)")

plt.plot([0,50], [150,150], 'k--',label = "True azimuth angle")

plt.xlabel('Elevation angle in degrees')
plt.ylabel('Azimuth angle in degrees')
plt.title('Estimated azimuth angle versus elevation of the source')
plt.legend()

# print("Compare the rate of change of the estimated azimuth angle when true azimuth for the sound source is 330 (-30) degrees")
# if(abs(m_Azimuth_Angle_150_estimated_T1)>abs(m_Azimuth_Angle_150_estimated_T2)):
#     print("The rate of change of estimated angle using ch13(T1) is larger than the estimated angle using ch23 (T2) ")
# elif(abs(m_Azimuth_Angle_150_estimated_T1)<abs(m_Azimuth_Angle_150_estimated_T2)):
#     print("The rate of change of estimated angle using ch23(T2) is larger than the estimated angle using ch13 (T1) ")
# else:
#     print("The rate of change of estimated angle using ch13(T1) is equal to the estimated angle using ch23 (T2) ")
    
    
print("The slope of T1 is: ",m_Azimuth_Angle_150_estimated_T1 )
print("The slope of T2 is: ",m_Azimuth_Angle_150_estimated_T2 )
print("The slope of T3 is: ",m_Azimuth_Angle_150_estimated_T3 )
# Out:
# The slope of T1 is:  0.2058801818181842
# The slope of T2 is:  -0.5598874545454529
# The slope of T3 is:  -0.015450181818179835

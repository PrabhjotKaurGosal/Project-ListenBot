# %%
# This code analyzes the data through plotting for different directions of the sound source 
# at different distances and true azimuths
#  Estimated Azimuth angle Versus True Azimuth angle

import os
import matplotlib.pyplot as plt
import numpy as np
import librosa
import wave
import librosa as lr
from scipy import signal
from scipy.fftpack import fft,fft2, fftshift, ifft
import math
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from sklearn import preprocessing
import librosa.display

# %%
TrueAzimuth_Angle = [0,30,60,90,120,150,180,-150,-120,-90,-60,-30]

# %%
# 0 degree elevation

# The elements in the array are from 0 degree to 330 degrees of azimuth angle (Estimated azimuth)
Azimuth_Angle_estimated_0degElv_1Meter = [-1.2258,27.4167,63.6506,98.1068,122.6698,153.2215,173.3923,-147.7159,-118.3947,-90.8371,-61.4835,-29.5949]
Azimuth_Angle_estimated_0degElv_2Meter = [-1.5608,27.4167,54.4636,91.8167,119.3732,152.8404,173.3923,-147.7159,-115.6754,-93.4334,-60.7860,-30.4839]
Azimuth_Angle_estimated_0degElv_3Meter = [-1.2255,23.1637,59.5194,92.4226,117.9570,155.4823,173.3923,-145.5151,-114.3392,-92.1066,-61.8343,-30.7803]

# Absolute error in estimation of azimuth angle
Azimuth_Angle_estimated_0degElv_1Meter_AbsErr = abs(np.array(Azimuth_Angle_estimated_0degElv_1Meter) - np.array(TrueAzimuth_Angle))
Azimuth_Angle_estimated_0degElv_2Meter_AbsErr = abs(np.array(Azimuth_Angle_estimated_0degElv_2Meter) - np.array(TrueAzimuth_Angle))
Azimuth_Angle_estimated_0degElv_3Meter_AbsErr = abs(np.array(Azimuth_Angle_estimated_0degElv_3Meter) - np.array(TrueAzimuth_Angle))

# %%
# 18.77 degree elevation

# The elements in the array are from 0 degree to 330 degrees of azimuth angle (Estimated azimuth)
Azimuth_Angle_estimated_18degElv_1Meter = [-4.4250,31.1320,60.2178,88.7888,130.4641,154.8576,161.6768,-139.0376,-115.2288,-86.9327,-56.7024,-31.5711]
Azimuth_Angle_estimated_18degElv_2Meter = [-4.8592,29.3220,63.3833,98.8238,129.7631,153.5984,162.6976,-139.2387,-113.4565,-86.9352,-63.0157,-31.0767]
Azimuth_Angle_estimated_18degElv_3Meter = [-2.5606,32.2840,63.6508,112.3622,124.5109,156.9670,158.4272,-142.4265,-113.6763,-85.6648,-59.0643,-30.4839]

# Absolute error in estimation of azimuth angle
Azimuth_Angle_estimated_18degElv_1Meter_AbsErr = abs(np.array(Azimuth_Angle_estimated_18degElv_1Meter) - np.array(TrueAzimuth_Angle))
Azimuth_Angle_estimated_18degElv_2Meter_AbsErr = abs(np.array(Azimuth_Angle_estimated_18degElv_2Meter) - np.array(TrueAzimuth_Angle))
Azimuth_Angle_estimated_18degElv_3Meter_AbsErr = abs(np.array(Azimuth_Angle_estimated_18degElv_3Meter) - np.array(TrueAzimuth_Angle))

# %%
# 22.29 degree elevation

# The elements in the array are from 0 degree to 330 degrees of azimuth angle (Estimated azimuth)
Azimuth_Angle_estimated_22degElv_1Meter = [-5.1846,35.1698,62.0626,89.7981,132.4842,156.7199,159.6602,-140.4896,-114.5624,-84.9612,-56.2646,-30.7801]
Azimuth_Angle_estimated_22degElv_2Meter = [-4.7512,31.5160,67.4185,105.4824,130.8118,155.2308,160.4765,-139.5837,-114.3426,-87.2894,-62.5462,-29.6936]
Azimuth_Angle_estimated_22degElv_3Meter = [-3.8802,33.4005,64.3245,117.2236,129.0504,157.3356,162.0056,-140.4831,-113.0168,-83.5815,-58.3839,-30.4839]

# Absolute error in estimation of azimuth angle
Azimuth_Angle_estimated_22degElv_1Meter_AbsErr = abs(np.array(Azimuth_Angle_estimated_22degElv_1Meter) - np.array(TrueAzimuth_Angle))
Azimuth_Angle_estimated_22degElv_2Meter_AbsErr = abs(np.array(Azimuth_Angle_estimated_22degElv_2Meter) - np.array(TrueAzimuth_Angle))
Azimuth_Angle_estimated_22degElv_3Meter_AbsErr = abs(np.array(Azimuth_Angle_estimated_22degElv_3Meter) - np.array(TrueAzimuth_Angle))

# %%
# Create subplots
fig = plt.figure()
fig.set_figheight(15)
fig.set_figwidth(20)

# Adds subplot on position 1
ax = fig.add_subplot(331)
ax.plot(TrueAzimuth_Angle, Azimuth_Angle_estimated_0degElv_1Meter,'ro',label = "Est_azimuth_1Meter_0Elv")
ax.plot([-150,180], [-150,180], 'k--',label = "True azimuth angle")
ax.set_yticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax.set_xticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax.legend(loc='upper left')
ax.set_ylabel('Estimated Azimuth angle in degrees')
ax.set_title('Est azimuth Vs True azimuth at 1M and 0Elv')

# Adds subplot on position 2
ax1 = fig.add_subplot(332)
ax1.plot(TrueAzimuth_Angle, Azimuth_Angle_estimated_18degElv_1Meter,'bo',label = "Est_azimuth_1Meter_18.77Elv")
ax1.plot([-150,180], [-150,180], 'k--',label = "True azimuth angle")
ax1.set_yticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax1.set_xticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax1.legend(loc='upper left')
ax1.set_title('Est azimuth Vs True azimuth at 1M and 18.77Elv')

# Adds subplot on position 3
ax2 = fig.add_subplot(333)
ax2.plot(TrueAzimuth_Angle, Azimuth_Angle_estimated_22degElv_1Meter,'yo',label = "Est_azimuth_1Meter_22.29Elv")
ax2.plot([-150,180], [-150,180], 'k--',label = "True azimuth angle")
ax2.set_yticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax2.set_xticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax2.legend(loc='upper left')
ax2.set_title('Est azimuth Vs True azimuth at 1M and 22.29Elv')

# Adds subplot on position 4
ax3 = fig.add_subplot(334)
ax3.plot(TrueAzimuth_Angle, Azimuth_Angle_estimated_0degElv_2Meter,'ro',label = "Est_azimuth_2Meter_0Elv")
ax3.plot([-150,180], [-150,180], 'k--',label = "True azimuth angle")
ax3.set_yticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax3.set_xticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax3.legend(loc='upper left')
ax3.set_ylabel('Estimated Azimuth angle in degrees')
ax3.set_title('Est azimuth Vs True azimuth at 2M and 0Elv')

# Adds subplot on position 5
ax4 = fig.add_subplot(335)
ax4.plot(TrueAzimuth_Angle, Azimuth_Angle_estimated_18degElv_2Meter,'bo',label = "Est_azimuth_2Meter_18.77Elv")
ax4.plot([-150,180], [-150,180], 'k--',label = "True azimuth angle")
ax4.set_yticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax4.set_xticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax4.legend(loc='upper left')
ax4.set_title('Est azimuth Vs True azimuth at 2M and 18.77Elv')

# Adds subplot on position 6
ax5 = fig.add_subplot(336)
ax5.plot(TrueAzimuth_Angle, Azimuth_Angle_estimated_22degElv_2Meter,'yo',label = "Est_azimuth_2Meter_22.29Elv")
ax5.plot([-150,180], [-150,180], 'k--',label = "True azimuth angle")
ax5.set_yticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax5.set_xticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax5.legend(loc='upper left')
ax5.set_title('Est azimuth Vs True azimuth at 2M and 22.29Elv')

# Adds subplot on position 7
ax6 = fig.add_subplot(337)
ax6.plot(TrueAzimuth_Angle, Azimuth_Angle_estimated_0degElv_3Meter,'ro',label = "Est_azimuth_3Meter_0Elv")
ax6.plot([-150,180], [-150,180], 'k--',label = "True azimuth angle")
ax6.set_yticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax6.set_xticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax6.legend(loc='upper left')
ax6.set_xlabel('True Azimuth angle in degrees')
ax6.set_ylabel('Estimated Azimuth angle in degrees')
ax6.set_title('Est azimuth Vs True azimuth at 3M and 0Elv')

# Adds subplot on position 8
ax7 = fig.add_subplot(338)
ax7.plot(TrueAzimuth_Angle, Azimuth_Angle_estimated_18degElv_3Meter,'bo',label = "Est_azimuth_3Meter_18.77Elv")
ax7.plot([-150,180], [-150,180], 'k--',label = "True azimuth angle")
ax7.set_yticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax7.set_xticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax7.legend(loc='upper left')
ax7.set_xlabel('True Azimuth angle in degrees')
ax7.set_title('Est azimuth Vs True azimuth at 3M and 18.77Elv')

# Adds subplot on position 9
ax8 = fig.add_subplot(339)
ax8.plot(TrueAzimuth_Angle, Azimuth_Angle_estimated_22degElv_3Meter,'yo',label = "Est_azimuth_3Meter_22.29Elv")
ax8.plot([-150,180], [-150,180], 'k--',label = "True azimuth angle")
ax8.set_yticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax8.set_xticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax8.legend(loc='upper left')
ax8.set_xlabel('True Azimuth angle in degrees')
ax8.set_title('Est azimuth Vs True azimuth at 3M and 22.29Elv')

plt.show()

# %%
# Create subplots
fig = plt.figure()
fig.set_figheight(15)
fig.set_figwidth(20)

# Adds subplot on position 1
ax = fig.add_subplot(331)
ax.plot(TrueAzimuth_Angle, Azimuth_Angle_estimated_0degElv_1Meter_AbsErr,'ro',label = "Est_azimuth_Err_1Meter_0Elv")
ax.plot([-150,180], [5,5], 'k--',label = "Upper limit for allowed error")
ax.set_ylim(bottom=0, top=22)
ax.legend(loc='upper left')
ax.set_xticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax.set_ylabel('Error in Azimuth estimation in degrees')
ax.set_title('Estimation Error Vs True azimuth at 1Meter and 0 Elv')

# Adds subplot on position 2
ax2 = fig.add_subplot(332)
ax2.plot(TrueAzimuth_Angle, Azimuth_Angle_estimated_18degElv_1Meter_AbsErr,'bo',label = "Est_azimuth_Err_1Meter_18.77Elv")
ax2.plot([-150,180], [5,5], 'k--',label = "Upper limit for allowed error")
ax2.set_ylim(bottom=0, top=22)
ax2.legend(loc='upper left')
ax2.set_xticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax2.set_title('Estimation Error Vs True azimuth at 1Meter and 18.77 Elv')

# Adds subplot on position 3
ax3 = fig.add_subplot(333)
ax3.plot(TrueAzimuth_Angle, Azimuth_Angle_estimated_22degElv_1Meter_AbsErr,'yo',label = "Est_azimuth_Err_1Meter_22.29Elv")
ax3.plot([-150,180], [5,5], 'k--',label = "Upper limit for allowed error")
ax3.set_ylim(bottom=0, top=22)
ax3.legend(loc='upper left')
ax3.set_xticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax3.set_title('Estimation Error Vs True azimuth at 1Meter and 22.29 Elv')

# Adds subplot on position 1
ax4 = fig.add_subplot(334)
ax4.plot(TrueAzimuth_Angle, Azimuth_Angle_estimated_0degElv_2Meter_AbsErr,'ro',label = "Est_azimuth_Err_2Meter_0Elv")
ax4.plot([-150,180], [5,5], 'k--',label = "Upper limit for allowed error")
ax4.set_ylim(bottom=0, top=22)
ax4.set_xticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax4.legend(loc='upper left')
ax4.set_ylabel('Error in Azimuth estimation in degrees')
ax4.set_title('Estimation Error Vs True azimuth at 2Meter and 0 Elv')

# Adds subplot on position 2
ax5 = fig.add_subplot(335)
ax5.plot(TrueAzimuth_Angle, Azimuth_Angle_estimated_18degElv_2Meter_AbsErr,'bo',label = "Est_azimuth_Err_2Meter_18.77Elv")
ax5.plot([-150,180], [5,5], 'k--',label = "Upper limit for allowed error")
ax5.set_ylim(bottom=0, top=22)
ax5.set_xticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax5.legend(loc='upper left')
ax5.set_title('Estimation Error Vs True azimuth at 2Meter and 18.77 Elv')

# Adds subplot on position 3
ax6 = fig.add_subplot(336)
ax6.plot(TrueAzimuth_Angle, Azimuth_Angle_estimated_22degElv_2Meter_AbsErr,'yo',label = "Est_azimuth_Err_2Meter_22.29Elv")
ax6.plot([-150,180], [5,5], 'k--',label = "Upper limit for allowed error")
ax6.set_ylim(bottom=0, top=22)
ax6.set_xticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax6.legend(loc='upper left')
ax6.set_title('Estimation Error Vs True azimuth at 2Meter and 22.29 Elv')

# Adds subplot on position 1
ax7 = fig.add_subplot(337)
ax7.plot(TrueAzimuth_Angle, Azimuth_Angle_estimated_0degElv_3Meter_AbsErr,'ro',label = "Est_azimuth_Err_3Meter_0Elv")
ax7.plot([-150,180], [5,5], 'k--',label = "Upper limit for allowed error")
ax7.set_ylim(bottom=0, top=22)
ax7.set_xticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax7.legend(loc='upper left')
ax7.set_xlabel('True azimuth angle in degrees')
ax7.set_ylabel('Error in Azimuth estimation in degrees')
ax7.set_title('Estimation Error Vs True azimuth at 3Meter and 0 Elv')

# Adds subplot on position 2
ax8 = fig.add_subplot(338)
ax8.plot(TrueAzimuth_Angle, Azimuth_Angle_estimated_18degElv_3Meter_AbsErr,'bo',label = "Est_azimuth_Err_3Meter_18.77Elv")
ax8.plot([-150,180], [5,5], 'k--',label = "Upper limit for allowed error")
ax8.set_ylim(bottom=0, top=22)
ax8.set_xticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax8.legend(loc='upper left')
ax8.set_xlabel('True azimuth angle in degrees')
ax8.set_title('Estimation Error Vs True azimuth at 3Meter and 18.77 Elv')

# Adds subplot on position 3
ax9 = fig.add_subplot(339)
ax9.plot(TrueAzimuth_Angle, Azimuth_Angle_estimated_22degElv_3Meter_AbsErr,'yo',label = "Est_azimuth_Err_3Meter_22.29Elv")
ax9.plot([-150,180], [5,5], 'k--',label = "Upper limit for allowed error")
ax9.set_ylim(bottom=0, top=22)
ax9.set_xticks([0,30,60,90,120,150,180,-150,-120,-90,-60,-30])
ax9.legend(loc='upper left')
ax9.set_xlabel('True azimuth angle in degrees')
ax9.set_title('Estimation Error Vs True azimuth at 3Meter and 22.29 Elv')
plt.show()
